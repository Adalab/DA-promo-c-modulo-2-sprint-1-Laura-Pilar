# %% [markdown]
# # PANDAS VI: Groupby

# %% [markdown]
# Es el momento de poner en práctica los groupby de pandas. Para esto vamos a trabajar con el csv creado en el ejercicio de pair programming anterior.
#
# ##### El objetivo de este ejercicio es agrupar los datos para contestar las siguientes preguntas:

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("datos/attacks_pandas5.csv")
df.head(1)
# Out:
#   case_number  unnamed:_0_x    year     type country        area  \
# 0  2018.06.25             0  2018.0  Boating     USA  California
#
#                       location  activity         name sex_ age   time  \
# 0  Oceanside, San Diego County  Paddling  Julie Wolfe    F  57  18h00
#
#       species_                                               href      siglo  \
# 0  White shark  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI
#
#   fatal_(y/n)                                             injury         date
# 0           N  No injury to occupant, outrigger canoe and pad...  25-Jun-2018

# %% [markdown]
# ### 1. ¿Cuántos ataques hubo por país? Devuelve un DataFrame.
# 📌 NOTA: Ordena los resultados de mayor a menor.
#
# Esto todavía no lo hemos visto, pero un DataFrame lo podemos ordenar con .sort_values(). Hay más información sobre esto en el gitbook.

# %%
df_pais =  pd.DataFrame(df.groupby("country")["case_number"].count().sort_values(ascending=False))
df_pais.head()
# Out:
#               case_number
# country
# USA                   741
# AUSTRALIA             343
# SOUTH AFRICA          234
# BAHAMAS                29
# NEW ZEALAND            21

# %% [markdown]
# ### 2. ¿Cuántos ataques ha habido por año?
#
# Devuelve un DataFrame. De nuevo ordena los resultados de mayor a menor.

# %%
df_año =  pd.DataFrame(df.groupby("year")["case_number"].count().sort_values(ascending=False))
df_año.head(10)
# Out:
#         case_number
# year
# 0.0             125
# 2015.0           68
# 2007.0           57
# 2012.0           54
# 2002.0           53
# 2013.0           48
# 2005.0           45
# 2003.0           44
# 2009.0           42
# 2008.0           40

# %% [markdown]
# ### 3. ¿Cuántos ataques hubo por año y sexo?
# Devolved un DataFrame solo del año 2000 en adelante.

# %%
df_2000 = df[(df["year"] > 2000)]

df_año_sexo =  pd.DataFrame(df_2000.groupby(["year", "sex_"])["case_number"].count())
df_año_sexo.head(10)
# Out:
#              case_number
# year   sex_
# 2001.0 F               3
#        M              26
# 2002.0 F               6
#        M              47
# 2003.0 F               6
#        M              38
# 2004.0 F               4
#        M              35
#        lli             1
# 2005.0 F               7

# %% [markdown]
# ### 4. Primero extraed solo las filas que correspondan a USA, AUSTRALIA y SOUTH AFRICA.

# %%
df_paises = df[(df["country"] == "USA") | (df["country"] == "AUSTRALIA") | (df["country"] == "SOUTH AFRICA")]
df_paises.head()
# Out:
#     case_number  unnamed:_0_x    year        type       country  \
# 0    2018.06.25             0  2018.0     Boating           USA
# 2  2018.05.26.b             8  2018.0  Unprovoked           USA
# 3    2018.05.24            10  2018.0    Provoked     AUSTRALIA
# 6  2018.04.25.a            21  2018.0  Unprovoked     AUSTRALIA
# 8    2018.04.22            24  2018.0  Unprovoked  SOUTH AFRICA
#
#                     area                        location        activity  \
# 0             California     Oceanside, San Diego County        Paddling
# 2                Florida    Cocoa Beach, Brevard  County         Walking
# 3             Queensland                 Cairns Aquarium  Feeding sharks
# 6      Western Australia         Surfers Point, Prevelly         Surfing
# 8  Western Cape Province  Robberg Beach, Plettenberg Bay   Paddle-skiing
#
#           name sex_ age     time            species_  \
# 0  Julie Wolfe    F  57    18h00         White shark
# 2    Cody High    M  15    17h00      Bull shark, 6'
# 3         male    M  32  Morning     Grey reef shark
# 6    Rob Bruce    M  60    09h30           3 m shark
# 8         male    M  33    09h40  White shark, 2.5 m
#
#                                                 href      siglo fatal_(y/n)  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
# 6  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
#
#                                               injury         date
# 0  No injury to occupant, outrigger canoe and pad...  25-Jun-2018
# 2                              Lower left leg bitten  26-May-2018
# 3  Minor bite to hand by captive shark. PROVOKED ...  24-May-2018
# 6              No injury, knocked off board by shark  25-Apr-2018
# 8                   No injury, shark bit hole in ski  22-Apr-2018

# %%
df_paises_letal = df_paises[(df_paises["injury"] == "FATAL")]
df_paises_letal.head()
# Out:
#       case_number  unnamed:_0_x    year        type    country  \
# 41   2017.04.17.a           155  2017.0  Unprovoked  AUSTRALIA
# 68   2016.06.05.a           267  2016.0  Unprovoked  AUSTRALIA
# 70     2016.05.31           271  2016.0  Unprovoked  AUSTRALIA
# 117    2015.07.25           385  2015.0  Unprovoked  AUSTRALIA
# 146    2015.02.09           448  2015.0  Unprovoked  AUSTRALIA
#
#                   area                        location  \
# 41   Western Australia          Kelpies near Wylie Bay
# 68   Western Australia                        Mindarie
# 70   Western Australia          Falcon Beach, Mandurah
# 117           Tasmania  Lachan Island, Mercury Passage
# 146    New South Wales                    Shelly Beach
#
#                      activity              name sex_ age   time  \
# 41                    Surfing  Laeticia Brouwer    F  17  16h00
# 68                     Diving    Doreen Collyer    F  60  11h30
# 70                    Surfing       Ben Gerring    M  29  16h00
# 117  Scallop diving on hookah    Damien Johnson    M  46  10h00
# 146                   Surfing  Tadashi Nakahara    M  41  10h00
#
#                       species_  \
# 41                 White shark
# 68                  3+ m shark
# 70                 White shark
# 117  White shark, 3.9 to 4.2 m
# 146           3.5 to 4 m shark
#
#                                                   href      siglo fatal_(y/n)  \
# 41   http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           Y
# 68   http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           Y
# 70   http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           Y
# 117  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           Y
# 146  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           Y
#
#     injury         date
# 41   FATAL  17-Apr-2017
# 68   FATAL  05-Jun-2016
# 70   FATAL  31-May-2016
# 117  FATAL  25-Jul-2015
# 146  FATAL  09-Feb-2015

# %% [markdown]
# ¿Cuántos de los ataques fueron letales por sexo? Devuelve un DataFrame.

# %%
df_pais_sexo = pd.DataFrame(df_paises_letal.groupby("sex_")["case_number"].count())
df_pais_sexo.head()
# Out:
#       case_number
# sex_
# F               9
# M              78

# %% [markdown]
# ### 5. ¿En qué país hubo más ataques?
# Usando el DataFrame creado en el ejercicio anterior.

# %%
df_pais_sexo2 = pd.DataFrame(df_paises_letal.groupby("country")["case_number"].count())
df_pais_sexo2.head()
# Out:
#               case_number
# country
# AUSTRALIA              52
# SOUTH AFRICA           18
# USA                    17

# %% [markdown]
# ### 6. ¿Qué y cuántos tipos de ataques hubo por país?

# %%
df_pais_sexo2 = pd.DataFrame(df_paises_letal.groupby(["country", "type"])["case_number"].count())
df_pais_sexo2.head()
# Out:
#                          case_number
# country      type
# AUSTRALIA    Invalid               1
#              Unprovoked           51
# SOUTH AFRICA Unprovoked           18
# USA          Invalid               2
#              Unprovoked           15
