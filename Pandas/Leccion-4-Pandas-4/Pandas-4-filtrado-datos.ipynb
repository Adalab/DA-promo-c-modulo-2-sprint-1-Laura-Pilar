# %% [markdown]
# # PANDAS IV: Filtrado de datos

# %% [markdown]
# Hoy seguiremos trabajando con el csv de ataques que exploramos ayer. Para eso, ayer guardasteis al final del pair programming al que le habíamos elimiando algunas columnas. Utilizad ese fichero.
#
# En la lección de hoy tendréis que ir contestando una serie de preguntas que os planteamos. Para ello tendréis que aplicar los conocimientos adquiridos en la clase invertida sobre como filtrar datos en el DataFrame y como reemplazar valores en el DataFrame.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Cargad el csv que guardasteis ayer.
#
# Antes de seguir con las preguntas, este DataFrame está terriblemente sucio. En las próximas sesiones lo iremos limpiando. Para evitar posibles errores con los nulos vamos a eliminar todos los nulos del DataFrame.
#
# Para ello vamos a utilizar el método .dropna() de pandas. Tendréis que ejecutar la siguiente línea de código para eliminar los nulos del DataFrame y poder seguir haciendo el resto de los ejercicios. ¿Cuántas filas se han eliminado con esta línea de código?

# %%
df = pd.read_csv('datos/attacks_pandas3.csv')
df.head()
# Out:
#   case_number  unnamed:_0    year        type    country             area  \
# 0  2018.06.25           0  2018.0     Boating        USA       California
# 1  2018.06.18           1  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09           2  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08           3  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04           4  2018.0    Provoked     MEXICO           Colima
#
#                          location     activity             name sex_  age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#             time         species_  \
# 0          18h00      White shark
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6114 entries, 0 to 6113
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   case_number  6113 non-null   object
#  1   unnamed:_0   6114 non-null   int64
#  2   year         6114 non-null   float64
#  3   type         6110 non-null   object
#  4   country      6074 non-null   object
#  5   area         5706 non-null   object
#  6   location     5626 non-null   object
#  7   activity     5603 non-null   object
#  8   name         5914 non-null   object
#  9   sex_         5564 non-null   object
#  10  age          3448 non-null   object
#  11  time         2934 non-null   object
#  12  species_     3409 non-null   object
#  13  href         6114 non-null   object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 668.8+ KB

# %%
df.dropna(inplace = True)
df.head()
# Out:
#      case_number  unnamed:_0    year        type    country        area  \
# 0     2018.06.25           0  2018.0     Boating        USA  California
# 6   2018.06.03.a           6  2018.0  Unprovoked     BRAZIL  Pernambuco
# 8   2018.05.26.b           8  2018.0  Unprovoked        USA     Florida
# 10    2018.05.24          10  2018.0    Provoked  AUSTRALIA  Queensland
# 13  2018.05.13.a          13  2018.0     Invalid    ENGLAND    Cornwall
#
#                         location        activity                    name sex_  \
# 0    Oceanside, San Diego County        Paddling             Julie Wolfe    F
# 6          Piedade Beach, Recife        Swimming  Jose Ernesto da Silva     M
# 8   Cocoa Beach, Brevard  County         Walking               Cody High    M
# 10               Cairns Aquarium  Feeding sharks                    male    M
# 13                Off Land's End         Fishing            Max Berryman    M
#
#    age            time          species_  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1502 entries, 0 to 5905
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   case_number  1502 non-null   object
#  1   unnamed:_0   1502 non-null   int64
#  2   year         1502 non-null   float64
#  3   type         1502 non-null   object
#  4   country      1502 non-null   object
#  5   area         1502 non-null   object
#  6   location     1502 non-null   object
#  7   activity     1502 non-null   object
#  8   name         1502 non-null   object
#  9   sex_         1502 non-null   object
#  10  age          1502 non-null   object
#  11  time         1502 non-null   object
#  12  species_     1502 non-null   object
#  13  href         1502 non-null   object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 176.0+ KB

# %% [markdown]
# Se han eliminado 4612 filas.

# %% [markdown]
# ### 2. ¿Cuál es el número de ataques que se han producido en Estados Unidos?

# %%
df_usa = df[df["country"] == "USA"]
df_usa.head()
# Out:
#      case_number  unnamed:_0    year        type country        area  \
# 0     2018.06.25           0  2018.0     Boating     USA  California
# 8   2018.05.26.b           8  2018.0  Unprovoked     USA     Florida
# 35    2018.03.31          35  2018.0  Unprovoked     USA      Hawaii
# 53    2017.12.31          53  2017.0  Unprovoked     USA      Hawaii
# 60    2017.11.24          60  2017.0  Unprovoked     USA  California
#
#                             location                 activity  \
# 0        Oceanside, San Diego County                 Paddling
# 8       Cocoa Beach, Brevard  County                  Walking
# 35                       Kukio Beach  Stand-Up Paddleboarding
# 53              Hultin's Beach, Oahu                  Surfing
# 60  Stillwater Cove, Monterey County             Spearfishing
#
#                 name sex_ age   time            species_  \
# 0        Julie Wolfe    F  57  18h00         White shark
# 8          Cody High    M  15  17h00      Bull shark, 6'
# ...

# %%
df_usa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 719 entries, 0 to 5297
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   case_number  719 non-null    object
#  1   unnamed:_0   719 non-null    int64
#  2   year         719 non-null    float64
#  3   type         719 non-null    object
#  4   country      719 non-null    object
#  5   area         719 non-null    object
#  6   location     719 non-null    object
#  7   activity     719 non-null    object
#  8   name         719 non-null    object
#  9   sex_         719 non-null    object
#  10  age          719 non-null    object
#  11  time         719 non-null    object
#  12  species_     719 non-null    object
#  13  href         719 non-null    object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 84.3+ KB

# %% [markdown]
# ### 3. ¿Y en España?

# %%
df_spain = df[df["country"] == "SPAIN"]
df_spain.head()
# Out:
#        case_number  unnamed:_0    year        type country  \
# 98    2017.08.26.b          98  2017.0     Invalid   SPAIN
# 233     2016.07.29         234  2016.0  Unprovoked   SPAIN
# 377   2015.08.18.a         378  2015.0     Invalid   SPAIN
# 1007  2010.07.16.b        1011  2010.0    Provoked   SPAIN
# 2469    1993.09.03        2476  1993.0  Unprovoked   SPAIN
#
#                      area                        location  activity  \
# 98              Castellón                 Grao de Moncofa  Swimming
# 233     Alicante Province                Arenales del Sol  Swimming
# 377              Alicante        Poniente Beach, Benidorm  Swimming
# 1007  Grand Canary Island       Sardina del Norte, Gáldar  Swimming
# 2469         Costa Blanca  Playa de las Arenas, Valencia   Swimming
#
#                                      name sex_ age    time  \
# 98                                 female    F  11  Midday
# 233                                  male    M  40   11h30
# ...

# %%
df_spain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 98 to 2469
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   case_number  5 non-null      object
#  1   unnamed:_0   5 non-null      int64
#  2   year         5 non-null      float64
#  3   type         5 non-null      object
#  4   country      5 non-null      object
#  5   area         5 non-null      object
#  6   location     5 non-null      object
#  7   activity     5 non-null      object
#  8   name         5 non-null      object
#  9   sex_         5 non-null      object
#  10  age          5 non-null      object
#  11  time         5 non-null      object
#  12  species_     5 non-null      object
#  13  href         5 non-null      object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 600.0+ bytes

# %% [markdown]
# - ¿En qué regiones se han producido los ataques (columna location)?

# %%
# En Estados Unidos:

df_usa["location"].unique()
# Out:
# array(['Oceanside, San Diego County', 'Cocoa Beach, Brevard  County',
#        'Kukio Beach', "Hultin's Beach, Oahu",
#        'Stillwater Cove, Monterey County',
#        'Davidsons Beach, Kekaha, Kauai', 'Kama\x91ole Beach Park, Maui ',
#        'Rockaway', 'Ponce Inlet, Volusia County',
#        'Marconi Beach, Wellfleet, Barnstable County',
#        'Sea Pines Resort, Hilton Head Island, Beaufort County',
#        'Menauhant Beach, Falmouth,\nBarnstable County',
#        'Hilton Head Island, Beaufort County',
#        'Stearns Wharf, Santa Barbara',
#        'Seal Rock, Goleta Beach, Santa Barbara',
#        'Haulover Beach, Miami-Dade County', 'Sunset Beach, Orange County',
#        'Kekaha Beach, Kauai', 'Destin, Okaloosa County',
#        'New Smyrna Beach, Volusia County', 'Kamaole Beach Park I, Maui',
#        'Hooipa Beach Park, Maui', 'Ponte Vedra, St. Johns County',
#        'Makaha, Oahu', 'Maui', 'Surfside, Orange County',
# ...

# %%
# En España:

df_spain["location"].unique()
# Out:
# array(['Grao de Moncofa', 'Arenales del Sol', 'Poniente Beach, Benidorm',
#        'Sardina del Norte, Gáldar', 'Playa de las Arenas, Valencia '],
#       dtype=object)

# %% [markdown]
# - ¿Cuántos ataques se han producido en cada área (columna area)?

# %%
# En Estados Unidos:

df_usa["location"].value_counts()
# Out:
# New Smyrna Beach, Volusia County                        73
# Myrtle Beach, Horry County                               7
# Daytona Beach, Volusia County                            7
# Melbourne Beach, Brevard County                          6
# Ponce Inlet, New Smyrna Beach, Volusia County            5
#                                                         ..
# Majors Bay, Kaua'i                                       1
# Smith Point, Long Island                                 1
# Jupiter Inlet                                            1
# Normandy Beach, Hutchinson Island,  St. Lucie County     1
# Beach Haven, Ocean County                                1
# Name: location, Length: 534, dtype: int64

# %%
# En España:

df_spain["location"].value_counts()
# Out:
# Grao de Moncofa                   1
# Arenales del Sol                  1
# Poniente Beach, Benidorm          1
# Sardina del Norte, Gáldar         1
# Playa de las Arenas, Valencia     1
# Name: location, dtype: int64

# %% [markdown]
# ### 4. Extraed un DataFrame nuevo con los ataques que se han producido en Australia y Estados Unidos.
#
# 📌 Nota: Este ejercicio se puede resolver usando dos condiciones de filtrado o usando el método isin().
# Hacedlo con ambas herramientas.

# %%
df_usa_australia1 = df[(df["country"] == "USA") | (df["country"] == "AUSTRALIA")]
df_usa_australia1.head()
# Out:
#      case_number  unnamed:_0    year        type    country  \
# 0     2018.06.25           0  2018.0     Boating        USA
# 8   2018.05.26.b           8  2018.0  Unprovoked        USA
# 10    2018.05.24          10  2018.0    Provoked  AUSTRALIA
# 21  2018.04.25.a          21  2018.0  Unprovoked  AUSTRALIA
# 35    2018.03.31          35  2018.0  Unprovoked        USA
#
#                  area                      location                 activity  \
# 0          California   Oceanside, San Diego County                 Paddling
# 8             Florida  Cocoa Beach, Brevard  County                  Walking
# 10         Queensland               Cairns Aquarium           Feeding sharks
# 21  Western Australia       Surfers Point, Prevelly                  Surfing
# 35             Hawaii                   Kukio Beach  Stand-Up Paddleboarding
#
#            name sex_ age     time          species_  \
# 0   Julie Wolfe    F  57    18h00       White shark
# ...

# %%
df_usa_australia2 = df[df["country"].isin(["USA", "AUSTRALIA"])]
df_usa_australia2.head()
# Out:
#      case_number  unnamed:_0    year        type    country  \
# 0     2018.06.25           0  2018.0     Boating        USA
# 8   2018.05.26.b           8  2018.0  Unprovoked        USA
# 10    2018.05.24          10  2018.0    Provoked  AUSTRALIA
# 21  2018.04.25.a          21  2018.0  Unprovoked  AUSTRALIA
# 35    2018.03.31          35  2018.0  Unprovoked        USA
#
#                  area                      location                 activity  \
# 0          California   Oceanside, San Diego County                 Paddling
# 8             Florida  Cocoa Beach, Brevard  County                  Walking
# 10         Queensland               Cairns Aquarium           Feeding sharks
# 21  Western Australia       Surfers Point, Prevelly                  Surfing
# 35             Hawaii                   Kukio Beach  Stand-Up Paddleboarding
#
#            name sex_ age     time          species_  \
# 0   Julie Wolfe    F  57    18h00       White shark
# ...

# %% [markdown]
# - ¿Cuántos ataques se han producido en cada país?

# %%
df_usa_australia1["country"].value_counts()
# Out:
# USA          719
# AUSTRALIA    324
# Name: country, dtype: int64

# %% [markdown]
# - ¿Ha habido ataques en Australia a gente que estuviera remando (lo encontrareis como Paddling en el DataFrame en la columna activity)?

# %%
df_usa_australia2[(df_usa_australia2["country"] == "AUSTRALIA") & (df_usa_australia2["activity"] == "Paddling")].head()
# Out:
# Empty DataFrame
# Columns: [case_number, unnamed:_0, year, type, country, area, location, activity, name, sex_, age, time, species_, href]
# Index: []

# %%
df_usa_australia2["activity"].unique()
# Out:
# array(['Paddling', 'Walking', 'Feeding sharks', 'Surfing',
#        'Stand-Up Paddleboarding', 'Wading', 'Swimming', 'Spearfishing',
#        'Kayaking / Fishing', 'Snorkeling', 'SUP', 'Fishing', 'Kayaking',
#        'Body boarding', 'Scuba Diving', 'Surf fishing', 'Floating',
#        'SUP Foil boarding', 'Kite surfing', 'Floating in tube',
#        'Standing', 'Diving', 'Teasing a shark', 'Paddle boarding',
#        'Kayak Fishing', 'Surf-skiing', 'Scallop diving on hookah',
#        'Body boarding ', 'Playing in the water', 'Boogie boarding',
#        'Playing', 'Surf skiing ', 'Standing / Snorkeling', 'Rowing',
#        'Shark fishing', 'Fishing ', 'Kayaking ', 'Body surfing',
#        'Diving for lobsters', 'Kiteboarding', 'Diving ',
#        'Diving for Abalone', 'Casting a net', 'Boogie Boarding',
#        'Playing in the surf', 'Bodyboarding',
#        'Swimming or boogie boarding', 'Free diving ',
#        'Sitting in the water', 'Scuba diving', 'Diving, feeding sharks',
# ...

# %%
df_australia = df[df["country"] == "AUSTRALIA"]
df_australia.head()
# Out:
#      case_number  unnamed:_0    year        type    country  \
# 10    2018.05.24          10  2018.0    Provoked  AUSTRALIA
# 21  2018.04.25.a          21  2018.0  Unprovoked  AUSTRALIA
# 36    2018.03.14          36  2018.0  Unprovoked  AUSTRALIA
# 37  2018.03.09.b          37  2018.0  Unprovoked  AUSTRALIA
# 38  2018.03.09.a          38  2018.0  Unprovoked  AUSTRALIA
#
#                  area                 location        activity  \
# 10         Queensland          Cairns Aquarium  Feeding sharks
# 21  Western Australia  Surfers Point, Prevelly         Surfing
# 36  Western Australia           Waterman's Bay          Wading
# 37           Victoria                    Lorne        Swimming
# 38           Victoria                 Winkipop         Surfing
#
#                     name sex_ age     time         species_  \
# 10                  male    M  32  Morning  Grey reef shark
# 21             Rob Bruce    M  60    09h30        3 m shark
# ...

# %%
df_australia["activity"].unique()
# Out:
# array(['Feeding sharks', 'Surfing', 'Wading', 'Swimming', 'Walking',
#        'Kayaking / Fishing', 'Body boarding', 'Scuba Diving',
#        'Surf fishing', 'Fishing', 'Diving', 'Spearfishing', 'Surf-skiing',
#        'Scallop diving on hookah', 'Body boarding ', 'Surf skiing ',
#        'Rowing', 'Diving for lobsters', 'Snorkeling',
#        'Diving for Abalone', 'Paddle boarding', 'Bodyboarding',
#        'Scuba diving', 'Diving, feeding sharks',
#        'Washing sand off a speared fish', 'Wakeboarding',
#        'Diving for abalone', 'Kayaking',
#        'Diving, but on the surface when bitten by the shark',
#        "Accidentally stood on hooked shark's tail before attempting to gut it ",
#        'Swimming / jumping off a jetty',
#        'Scurfing (surfboard being  towed behind a boat)',
#        'Free diving & spearfishing',
#        'Scallop diving (using surface-supplied air & a POD) ',
#        'Windsurfing', 'Free diving for abalone',
# ...

# %% [markdown]
# - ¿Cuántos ataques se han producido en Australia antes del 2000?

# %%
df_australia[(df_australia["year"] < 2000)]
# Out:
#         case_number  unnamed:_0    year        type    country  \
# 2116     1999.05.29        2123  1999.0  Unprovoked  AUSTRALIA
# 2129     1999.02.23        2136  1999.0  Unprovoked  AUSTRALIA
# 2174   1998.06.28.a        2181  1998.0  Unprovoked  AUSTRALIA
# 2194  1998.01.28.R         2201  1998.0     Invalid  AUSTRALIA
# 2207     1997.11.09        2214  1997.0  Unprovoked  AUSTRALIA
# ...             ...         ...     ...         ...        ...
# 5359     1912.01.26        5375  1912.0  Unprovoked  AUSTRALIA
# 5481     1905.03.26        5498  1905.0  Unprovoked  AUSTRALIA
# 5631     1894.11.28        5648  1894.0  Unprovoked  AUSTRALIA
# 5667     1892.03.02        5684  1892.0    Provoked  AUSTRALIA
# 5797     1880.11.25        5814  1880.0  Unprovoked  AUSTRALIA
#
#                    area                                        location  \
# 2116    South Australia                  Hardwicke Bay, Yorke Peninsula
# ...

# %% [markdown]
# - ¿Y después del 2000?

# %%
df_australia[(df_australia["year"] > 2000)]
# Out:
#        case_number  unnamed:_0    year        type    country  \
# 10      2018.05.24          10  2018.0    Provoked  AUSTRALIA
# 21    2018.04.25.a          21  2018.0  Unprovoked  AUSTRALIA
# 36      2018.03.14          36  2018.0  Unprovoked  AUSTRALIA
# 37    2018.03.09.b          37  2018.0  Unprovoked  AUSTRALIA
# 38    2018.03.09.a          38  2018.0  Unprovoked  AUSTRALIA
# ...            ...         ...     ...         ...        ...
# 1876    2002.02.07        1883  2002.0     Boating  AUSTRALIA
# 1877  2002.01.30.b        1884  2002.0  Unprovoked  AUSTRALIA
# 1888    2001.10.02        1895  2001.0  Unprovoked  AUSTRALIA
# 1961  2001.04.02.a        1968  2001.0  Unprovoked  AUSTRALIA
# 1969    2001.02.04        1976  2001.0  Unprovoked  AUSTRALIA
#
#                    area                       location        activity  \
# 10           Queensland                Cairns Aquarium  Feeding sharks
# 21    Western Australia        Surfers Point, Prevelly         Surfing
# ...

# %% [markdown]
# ### 5. Extraed unicamente los ataques a mujeres.

# %%
df_mujeres = df[(df["sex_"] == "F")]
df_mujeres.head()
# Out:
#    case_number  unnamed:_0    year        type    country             area  \
# 0   2018.06.25           0  2018.0     Boating        USA       California
# 40  2018.02.23          40  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 53  2017.12.31          53  2017.0  Unprovoked        USA           Hawaii
# 71  2017.10.22          71  2017.0  Unprovoked  AUSTRALIA  South Australia
# 75  2017.10.05          75  2017.0  Unprovoked        USA           Hawaii
#
#                               location            activity              name  \
# 0          Oceanside, San Diego County            Paddling       Julie Wolfe
# 40  Little Congwong Beach, La Perouse             Swimming    Anna Shurapey
# 53                Hultin's Beach, Oahu             Surfing  Marjorie Mariano
# 71                         Normanville  Kayaking / Fishing    Sarah Williams
# 75          Kamaole Beach Park, Maui           Snorkeling            female
#
# ...

# %% [markdown]
# ### 6. ¿Cuántas mujeres fueron atacadas en España?

# %%
df_mujeres[(df_mujeres["country"] == "SPAIN")].head()
# Out:
#      case_number  unnamed:_0    year     type country       area  \
# 98  2017.08.26.b          98  2017.0  Invalid   SPAIN  Castellón
#
#            location  activity    name sex_ age    time  \
# 98  Grao de Moncofa  Swimming  female    F  11  Midday
#
#                           species_  \
# 98  Shark involvement questionable
#
#                                                  href
# 98  http://sharkattackfile.net/spreadsheets/pdf_di...

# %% [markdown]
# ### 7. Extraed los ataques que se hayan producido en el año 2000, 1997 y 2006.
# Utilizad el método isin() para resolver este ejercicio.

# %%
df[df["year"].isin([2000.0, 1997.0, 2006.0])].head()
# Out:
#      case_number  unnamed:_0    year        type       country  \
# 1407  2006.12.18        1412  2006.0  Unprovoked     AUSTRALIA
# 1408  2006.12.11        1413  2006.0  Unprovoked   NEW ZEALAND
# 1409  2006.12.10        1414  2006.0  Unprovoked           USA
# 1410  2006.12.06        1415  2006.0    Provoked  SOUTH AFRICA
# 1411  2006.12.02        1416  2006.0  Unprovoked     AUSTRALIA
#
#                    area                    location       activity  \
# 1407           Victoria      Winki Pop, Bells Beach        Surfing
# 1408       North Island            Raglan, Manu Bay        Surfing
# 1409         California  Dillon Beach, Marin County        Surfing
# 1410      KwaZulu-Natal                  Cape Vidal        Fishing
# 1411  Western Australia               Wharton Beach  Body boarding
#
#                       name sex_ age       time                   species_  \
# 1407          Peter Galvin    M  25      20h00           2.5 to 3 m shark
# ...

# %% [markdown]
# ### 8. Si extraemos los valores únicos de la columna species nos podemos dar cuenta que está un poco sucia y extraer informacion útil de la misma se puede convertir en algo difícil.
#
# En este ejercicio tendréis que extraer los ataques que han ocurrido por tiburón blanco (lo encontraremos en la columna species como algo que contenga white o White). Usad el método str.contains() para resolver este ejercicio.

# %%
especies = df[df["species_"].str.contains("white", "White", regex = True)]
especies.head()
# Out:
#       case_number  unnamed:_0    year        type    country  \
# 40     2018.02.23          40  2018.0  Unprovoked  AUSTRALIA
# 459    2015.01.06         460  2015.0  Unprovoked    BAHAMAS
# 495  2014.10.02.a         496  2014.0  Unprovoked  AUSTRALIA
# 553    2014.05.14         555  2014.0  Unprovoked  AUSTRALIA
# 567    2014.04.03         569  2014.0  Unprovoked  AUSTRALIA
#
#                   area                             location    activity  \
# 40     New South Wales   Little Congwong Beach, La Perouse     Swimming
# 459      Abaco Islands              Tahiti Beach, Elbow Cay  Snorkeling
# 495  Western Australia  Kelpids Beach, Wylie Bay, Esperance     Surfing
# 553    South Australia             Elliston, Eyre Peninsula     Surfing
# 567    New South Wales                               Tathra    Swimming
#
#                     name sex_ age         time  \
# 40        Anna Shurapey     F  55  19h00, Dusk
# 459            Lacy Webb    F  34        16h00
# ...

# %% [markdown]
# ### 9. Extraed ahora los ataques por tiburón blanco o tigre.
# Utilizad el método str.contains() para resolver este ejercicio.

# %%
df["species_"].unique()
# Out:
# array(['White shark', 'Tiger shark', "Bull shark, 6'", 'Grey reef shark',
#        'Invalid incident', '3 m shark', 'White shark, 2.5 m',
#        "Tiger shark, 12'", 'Wobbegong shark', '3.5 m shark',
#        '1.8 m shark', 'Juvenile white shark,  2.7 to 3.2 m',
#        'Bull shark, 2 m', 'small shark', 'White shark, 4.6 m',
#        '2 m shark', 'Wobbegong shark, 1 m', 'White shark, 4.5 m',
#        'Tiger shark, 8 to 10 feet', "8' shark", 'Questionable',
#        "5' to 6' shark", 'White shark, 3 to 3.5m ', 'White shark, 3 m',
#        'Shark involvement questionable', "White shark, 5' to 7'",
#        'Possibly a juvenile blacktip shark', "4' shark", 'A small shark',
#        "White shark, 11' to 13'", "White shark, 8' to 10'",
#        "Bull shark, 4' to 5'", 'White shark, 4 m',
#        'Shark involvement highly doubtful', "Bull shark, 5' to 7'",
#        'Bull shark, 4 m', 'Bull shark, 1 m',
#        'Shark involvement not confirmed', 'Wobbegong shark, 2m',
# ...

# %%
especies2 = df[(df["species_"].str.contains("[W|w]hite", regex = True)) | (df["species_"].str.contains("[T|t]iger", regex = True))]
especies2.head()
# Out:
#      case_number  unnamed:_0    year        type       country  \
# 0     2018.06.25           0  2018.0     Boating           USA
# 6   2018.06.03.a           6  2018.0  Unprovoked        BRAZIL
# 18  2018.04.28.b          18  2018.0  Unprovoked    COSTA RICA
# 23    2018.04.23          23  2018.0  Unprovoked      MALDIVES
# 24    2018.04.22          24  2018.0  Unprovoked  SOUTH AFRICA
#
#                      area                        location       activity  \
# 0              California     Oceanside, San Diego County       Paddling
# 6              Pernambuco           Piedade Beach, Recife       Swimming
# 18           Cocos Island                       Manuelita   Scuba diving
# 23      Alifu Alifu Atoll                       Madoogali        Fishing
# 24  Western Cape Province  Robberg Beach, Plettenberg Bay  Paddle-skiing
#
#                       name sex_ age            time            species_  \
# ...

# %% [markdown]
# ### 10. Utilizando la columna de year cread una nueva columna llamada siglo que tiene siglo-XX o siglo-XXI.
# Donde el año sea menor que 2000 pondremos siglo-XX y el resto de los años siglo-XXI.

# %%
df["siglo"] = np.where(df["year"] < 2000, "siglo-XX", "siglo-XXI")
df.head()
# Out:
#      case_number  unnamed:_0    year        type    country        area  \
# 0     2018.06.25           0  2018.0     Boating        USA  California
# 6   2018.06.03.a           6  2018.0  Unprovoked     BRAZIL  Pernambuco
# 8   2018.05.26.b           8  2018.0  Unprovoked        USA     Florida
# 10    2018.05.24          10  2018.0    Provoked  AUSTRALIA  Queensland
# 13  2018.05.13.a          13  2018.0     Invalid    ENGLAND    Cornwall
#
#                         location        activity                    name sex_  \
# 0    Oceanside, San Diego County        Paddling             Julie Wolfe    F
# 6          Piedade Beach, Recife        Swimming  Jose Ernesto da Silva     M
# 8   Cocoa Beach, Brevard  County         Walking               Cody High    M
# 10               Cairns Aquarium  Feeding sharks                    male    M
# 13                Off Land's End         Fishing            Max Berryman    M
#
#    age            time          species_  \
# ...

# %% [markdown]
# ### 11. Guardad como un archivo csv nuevo. Lo usaremos en el pair programming de mañana.

# %%
df.to_csv("datos/attacks_pandas4.csv")
