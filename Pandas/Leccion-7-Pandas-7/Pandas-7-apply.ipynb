# %% [markdown]
# # PANDAS VII: Apply

# %% [markdown]
# En el ejercicio de ayer estuvimos viendo el groupby y pudimos observar que los datos estaban un poco sucios... 😭.
#
# En los ejercicios de hoy pondremos en práctica los apply, y nos crearemos algunas funciones que nos van a permitir limpiar un poco los datos, para que podamos extraer conclusiones de una forma más sencilla.
#
# Manos a la obra 💪🏽! Los objetivos de la clase de hoy son:

# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv("datos/attacks_pandas5.csv")
df.head(1)
# Out:
#   case_number  unnamed:_0_x    year     type country        area  \
# 0  2018.06.25             0  2018.0  Boating     USA  California
#
#                       location  activity         name sex_ age   time  \
# 0  Oceanside, San Diego County  Paddling  Julie Wolfe    F  57  18h00
#
#       species_                                               href      siglo  \
# 0  White shark  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI
#
#    unnamed:_0_y fatal_(y/n)  \
# 0             0           N
#
#                                               injury         date
# 0  No injury to occupant, outrigger canoe and pad...  25-Jun-2018

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1672 entries, 0 to 1671
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   case_number   1672 non-null   object
#  1   unnamed:_0_x  1672 non-null   int64
#  2   year          1672 non-null   float64
#  3   type          1672 non-null   object
#  4   country       1662 non-null   object
#  5   area          1626 non-null   object
#  6   location      1621 non-null   object
#  7   activity      1641 non-null   object
#  8   name          1663 non-null   object
#  9   sex_          1658 non-null   object
#  10  age           1518 non-null   object
#  11  time          1512 non-null   object
#  12  species_      1546 non-null   object
#  13  href          1672 non-null   object
#  14  siglo         1672 non-null   object
#  15  unnamed:_0_y  1672 non-null   int64
#  16  fatal_(y/n)   1585 non-null   object
#  17  injury        1664 non-null   object
#  18  date          1672 non-null   object
#  19  mes_ataque    1672 non-null   object
#  20  fatal         1573 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 274.4+ KB

# %% [markdown]
# ### 1. Cread una columna nueva y una función que nos de el mes en el que ocurrió el ataque.
#
# Tened en cuenta que no todas las filas tienen la misma estructura y que puede que no haya la información de mes.
# En ese caso devolved un nulo (NaN).
#
# 💡 Pista 💡Podéis usar regex.

# %%
#  date es object
df["date"].unique()
# Out:
# array(['25-Jun-2018', '03-Jun-2018', '26-May-2018', ..., '1900-1905',
#        '1883-1889', '1845-1853'], dtype=object)

# %%
def mes_ataque(texto):
    # texto = str(texto)
    patron = "\-(Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)\-"
    try:
        return "".join(re.findall(patron, texto))
    except:
        return np.nan

# %%
a = '25-Jun-2018'
b = '03-Jun-2018'
c = '26-May-2018'
d = '1900-1905'
e = '1883-1889'
f = '1845-1853'

mes_ataque(d)
# Out:
# ''

# %%
df["mes_ataque"] = df["date"].apply(mes_ataque)

# %%
df.tail(20)
# Out:
#      case_number  unnamed:_0_x  year        type             country  \
# 1652     ND.0020          6282   0.0  Unprovoked           AUSTRALIA
# 1653     ND.0019          6283   0.0  Unprovoked                 USA
# 1654     ND.0018          6284   0.0  Unprovoked             VIETNAM
# 1655     ND.0017          6285   0.0  Unprovoked        SOUTH AFRICA
# 1656     ND.0016          6286   0.0  Unprovoked        SOUTH AFRICA
# 1657     ND.0015          6287   0.0  Unprovoked                FIJI
# 1658     ND.0014          6288   0.0  Unprovoked                 USA
# 1659     ND.0013          6289   0.0  Unprovoked        SOUTH AFRICA
# 1660     ND.0012          6290   0.0  Unprovoked        SOUTH AFRICA
# 1661     ND.0011          6291   0.0  Unprovoked               ASIA?
# 1662     ND.0010          6292   0.0  Unprovoked                 USA
# 1663     ND.0009          6293   0.0  Unprovoked           AUSTRALIA
# 1664     ND.0008          6294   0.0  Unprovoked           AUSTRALIA
# 1665     ND.0007          6295   0.0  Unprovoked           AUSTRALIA
# 1666     ND.0006          6296   0.0  Unprovoked           AUSTRALIA
# 1667     ND.0005          6297   0.0  Unprovoked           AUSTRALIA
# 1668     ND.0004          6298   0.0  Unprovoked           AUSTRALIA
# 1669     ND.0003          6299   0.0  Unprovoked                 USA
# 1670     ND.0002          6300   0.0  Unprovoked              PANAMA
# 1671     ND.0001          6301   0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                            area                                 location  \
# 1652                 Queensland                       Great Barrier Reef
# 1653                    Florida                 Gadsden Point, Tampa Bay
# 1654  Ba Ria-Vung Tau  Province                                 V?ng Tàu
# 1655              KwaZulu-Natal                                  Durban
# 1656              KwaZulu-Natal                                   Durban
# 1657               Moala Island                                      NaN
# 1658            North Carolina   Somewhere between Hatteras and Beaufort
# 1659              KwaZulu-Natal                                   Durban
# 1660              KwaZulu-Natal                                   Durban
# 1661                        NaN                                      NaN
# 1662                     Hawaii                                     Puna
# 1663                        NaN                                      NaN
# 1664                        NaN                                      NaN
# 1665                        NaN                                      NaN
# 1666            New South Wales
# 1667          Western Australia                              Roebuck Bay
# 1668          Western Australia                                      NaN
# 1669             North Carolina                           Ocracoke Inlet
# 1670                        NaN                     Panama Bay 8ºN, 79ºW
# 1671           Eastern Province      Below the English fort, Trincomalee
#
#                                          activity                   name sex_  \
# 1652                                          NaN      3 Japanese divers    M
# 1653                                      Fishing           James Kelley    M
# 1654                Swimming around anchored ship                crewman    M
# 1655  Crew swimming alongside their anchored ship                   male    M
# 1656                           4 men were bathing                   male    M
# 1657         Wreck of  large double sailing canoe             20 Fijians  NaN
# 1658                                     Swimming        "youthful male"    M
# 1659                                      Fishing     a native fisherman    M
# 1660                                       Wading       a young Scotsman    M
# 1661                                     Swimming             Mr. Masury    M
# 1662                                          NaN           A "chiefess"    F
# 1663                                      Fishing                    boy    M
# 1664                                      Fishing              fisherman    M
# 1665                                      Fishing              fisherman    M
# 1666                                     Swimming               Arab boy    M
# 1667                                       Diving                   male    M
# 1668                                 Pearl diving                  Ahmun    M
# 1669                                     Swimming  Coast Guard personnel    M
# 1670                                          NaN        Jules Patterson    M
# 1671                                     Swimming                   male    M
#
#       age time                                           species_  \
# 1652  NaN  NaN                                                NaN
# 1653  NaN  NaN                                                NaN
# 1654  NaN  NaN                                                NaN
# 1655  NaN  NaN                                                NaN
# 1656  NaN  NaN                                                NaN
# 1657  NaN  NaN                                                NaN
# 1658  NaN  NaN                                                NaN
# 1659  NaN  NaN                                                NaN
# 1660  NaN  NaN                                                NaN
# 1661  NaN  NaN                                                NaN
# 1662  NaN  NaN                                                NaN
# 1663  NaN  NaN                                       Blue pointer
# 1664  NaN  NaN                                       Blue pointer
# 1665  NaN  NaN                                      Blue pointers
# 1666  NaN  NaN  Said to involve a grey nurse shark that leapt ...
# 1667  NaN  NaN                                                NaN
# 1668  NaN  NaN                                                NaN
# 1669  NaN  NaN                                                NaN
# 1670  NaN  NaN                                                NaN
# 1671   15  NaN                                                NaN
#
#                                                    href     siglo  \
# 1652  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX
# 1653  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX
# 1654  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX
# 1655  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX
# 1656  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX
# 1657  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX
# 1658  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX
# 1659  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX
# 1660  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX
# 1661  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX
# 1662  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX
# 1663  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX
# 1664  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX
# 1665  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX
# 1666  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX
# 1667  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX
# 1668  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX
# 1669  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX
# 1670  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX
# 1671  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX
#
#       unnamed:_0_y fatal_(y/n)  \
# 1652          6266           Y
# 1653          6267           N
# 1654          6268           N
# 1655          6269           Y
# 1656          6270           Y
# 1657          6271           Y
# 1658          6272           N
# 1659          6273           Y
# 1660          6274           Y
# 1661          6275           N
# 1662          6276           N
# 1663          6277           Y
# 1664          6278           Y
# 1665          6279           Y
# 1666          6280           Y
# 1667          6281           Y
# 1668          6282           Y
# 1669          6283           Y
# 1670          6284           Y
# 1671          6285           Y
#
#                                                  injury  \
# 1652                                              FATAL
# 1653                                 2-inch lacerations
# 1654                                        Foot bitten
# 1655                                              FATAL
# 1656                                              FATAL
# 1657  FATAL, 18 people  were killed by sharks, 2 sur...
# 1658                                         "Lost leg"
# 1659  FATAL, body not recovered but shark was caught...
# 1660                     FATAL, leg stripped of flesh
# 1661                                       Foot severed
# 1662                                       Ankle bitten
# 1663  FATAL, knocked overboard by tail of shark & ca...
# 1664                                              FATAL
# 1665                                              FATAL
# 1666                                              FATAL
# 1667                                              FATAL
# 1668                                              FATAL
# 1669                                              FATAL
# 1670                                              FATAL
# 1671  FATAL. "Shark bit him in half, carrying away t...
#
#                                                    date mes_ataque
# 1652                                         1920 -1923
# 1653                                        Before 1921
# 1654                                        Before 1911
# 1655                                        Before 1921
# 1656                                        Before 1921
# 1657                                        Before 1917
# 1658                                 Before 17-Jul-1916        Jul
# 1659  No date (3 days after preceding incident) & pr...        Jul
# 1660                                 Before 19-Jul-1913        Jul
# 1661                                        Before 1911
# 1662                                         Circa 1862
# 1663                                        Before 1906
# 1664                                        Before 1906
# 1665                                        Before 1906
# 1666                                        Before 1906
# 1667                                        Before 1903
# 1668                                        Before 1903
# 1669                                          1900-1905
# 1670                                          1883-1889
# 1671                                          1845-1853

# %%
df["mes_ataque"].unique()
# Out:
# array(['Jun', 'May', 'Apr', 'Mar', 'Feb', 'Jan', 'Dec', 'Nov', 'Oct',
#        'Sep', 'Aug', 'Jul', '', 'MarMar'], dtype=object)

# %%
df["mes_ataque"].value_counts()
# Out:
#           181
# Aug       156
# Sep       153
# Oct       146
# Jul       143
# Jun       136
# Jan       127
# Apr       124
# May       105
# Dec       104
# Mar       101
# Nov        99
# Feb        96
# MarMar      1
# Name: mes_ataque, dtype: int64

# %% [markdown]
# ### 2. Vamos con la columna fatal_(y/n). Lo primero que tenéis que hacer es evaluar los valores únicos que hay.
#
# Esperaríamos tener solo dos valores: y y n, pero tristemente no será así 😭.
# Cread una columna nueva y una función que devuelva únicamente y o n y que devuelva un nulo (NaN) si no se encuentra el valor.

# %%
df["fatal_(y/n)"].unique()
# Out:
# array(['N', 'Y', nan, 'M', '2017', ' N', 'UNKNOWN'], dtype=object)

# %%
df["fatal_(y/n)"].value_counts()
# Out:
# N          1256
# Y           317
# UNKNOWN       8
#  N            2
# M             1
# 2017          1
# Name: fatal_(y/n), dtype: int64

# %%
def cambiar_fatal(fatal):
    if fatal == 'N':
        return fatal.lower()
    elif fatal == 'Y':
        return fatal.lower()
    else:
        return np.nan

# %%
df["fatal"] = df["fatal_(y/n)"].apply(cambiar_fatal)
df.head(10)
# Out:
#     case_number  unnamed:_0_x    year        type       country  \
# 0    2018.06.25             0  2018.0     Boating           USA
# 1  2018.06.03.a             6  2018.0  Unprovoked        BRAZIL
# 2  2018.05.26.b             8  2018.0  Unprovoked           USA
# 3    2018.05.24            10  2018.0    Provoked     AUSTRALIA
# 4  2018.05.13.a            13  2018.0     Invalid       ENGLAND
# 5  2018.04.28.b            18  2018.0  Unprovoked    COSTA RICA
# 6  2018.04.25.a            21  2018.0  Unprovoked     AUSTRALIA
# 7    2018.04.23            23  2018.0  Unprovoked      MALDIVES
# 8    2018.04.22            24  2018.0  Unprovoked  SOUTH AFRICA
# 9    2018.04.03            34  2018.0  Unprovoked  SOUTH AFRICA
#
#                     area                        location        activity  \
# 0             California     Oceanside, San Diego County        Paddling
# 1             Pernambuco           Piedade Beach, Recife        Swimming
# 2                Florida    Cocoa Beach, Brevard  County         Walking
# 3             Queensland                 Cairns Aquarium  Feeding sharks
# 4               Cornwall                  Off Land's End         Fishing
# 5           Cocos Island                       Manuelita    Scuba diving
# 6      Western Australia         Surfers Point, Prevelly         Surfing
# 7      Alifu Alifu Atoll                       Madoogali         Fishing
# 8  Western Cape Province  Robberg Beach, Plettenberg Bay   Paddle-skiing
# 9  Eastern Cape Province                 St. Francis Bay         Surfing
#
#                      name sex_  ...            time            species_  \
# 0             Julie Wolfe    F  ...           18h00         White shark
# 1  Jose Ernesto da Silva     M  ...  Late afternoon         Tiger shark
# 2               Cody High    M  ...           17h00      Bull shark, 6'
# 3                    male    M  ...         Morning     Grey reef shark
# 4            Max Berryman    M  ...           08h15    Invalid incident
# 5                    male    M  ...           10h40         Tiger shark
# 6               Rob Bruce    M  ...           09h30           3 m shark
# 7           Ahmed Rasheed    M  ...           21h50         Tiger shark
# 8                    male    M  ...           09h40  White shark, 2.5 m
# 9            Ross Spowart    M  ...           15h00         White shark
#
#                                                 href      siglo unnamed:_0_y  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI            0
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI            6
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI            8
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           10
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           13
# 5  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           18
# 6  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           21
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           23
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           24
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           34
#
#    fatal_(y/n)                                             injury  \
# 0            N  No injury to occupant, outrigger canoe and pad...
# 1            Y                                              FATAL
# 2            N                              Lower left leg bitten
# 3            N  Minor bite to hand by captive shark. PROVOKED ...
# 4            N  Injured by teeth of a dead porbeagle shark he ...
# 5            N                    No injury, shark bit scuba gear
# 6            N              No injury, knocked off board by shark
# 7            N                                 5-inch cut to hand
# 8            N                   No injury, shark bit hole in ski
# 9            N               Lacerations to left knee & lower leg
#
#           date mes_ataque fatal
# 0  25-Jun-2018        Jun     n
# 1  03-Jun-2018        Jun     y
# 2  26-May-2018        May     n
# 3  24-May-2018        May     n
# 4  13-May-2018        May     n
# 5  28-Apr-2018        Apr     n
# 6  25-Apr-2018        Apr     n
# 7  23-Apr-2018        Apr     n
# 8  22-Apr-2018        Apr     n
# 9  03-Apr-2018        Apr     n
#
# [10 rows x 21 columns]

# %%
df["fatal"].unique()
# Out:
# array(['n', 'y', nan], dtype=object)

# %%
df["fatal"].value_counts()
# Out:
# n    1256
# y     317
# Name: fatal, dtype: int64

# %%
df["fatal"].isnull().sum()
# Out:
# 99

# %% [markdown]
# ### 3. Seguid la misma lógica que en el ejercicio anterior pero con la columna sex.
#
# Pero en este caso vamos a incluir un retito más: En este caso querremos tener dos valores únicos F y M. De nuevo en la columna hay otros carácteres raros como 'M ', 'lli', 'N', '.'. En esos casos, queremos que se reemplacen por M o F de forma aleatoria (tendréis que usar la librería random). En caso de que sea nulo, que la función devuelva nulo (np.nan).

# %%
df["sex_"].value_counts()
# Out:
# M      1435
# F       222
# lli       1
# Name: sex_, dtype: int64

# %%
def cambiar_sex(sex):
    if sex == 'M' or sex == 'F':
        return sex
    elif:
        if str(sex).lower() == "nan":
            return np.nan
    else:
        aleatorio = np.random.randint(1,2, (1))

# %%
aleatorio = np.random.randint(1,3)
aleatorio
# Out:
# 1

# %% [markdown]
# ### 4. Una vez que hayáis terminado eliminad las columnas originales conservando las nuevas.

# %% [markdown]
# ### 5. Guardad el dataframe en un csv que usaremos más adelante.
