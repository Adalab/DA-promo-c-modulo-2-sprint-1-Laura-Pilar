# %% [markdown]
# # PANDAS VII: Apply

# %% [markdown]
# En el ejercicio de ayer estuvimos viendo el groupby y pudimos observar que los datos estaban un poco sucios... 😭.
#
# En los ejercicios de hoy pondremos en práctica los apply, y nos crearemos algunas funciones que nos van a permitir limpiar un poco los datos, para que podamos extraer conclusiones de una forma más sencilla.
#
# Manos a la obra 💪🏽! Los objetivos de la clase de hoy son:

# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv("datos/attacks_pandas5.csv")
df.head()
# Out:
#     case_number  unnamed:_0_x    year        type    country        area  \
# 0    2018.06.25             0  2018.0     Boating        USA  California
# 1  2018.06.03.a             6  2018.0  Unprovoked     BRAZIL  Pernambuco
# 2  2018.05.26.b             8  2018.0  Unprovoked        USA     Florida
# 3    2018.05.24            10  2018.0    Provoked  AUSTRALIA  Queensland
# 4  2018.05.13.a            13  2018.0     Invalid    ENGLAND    Cornwall
#
#                        location        activity                    name sex_  \
# 0   Oceanside, San Diego County        Paddling             Julie Wolfe    F
# 1         Piedade Beach, Recife        Swimming  Jose Ernesto da Silva     M
# 2  Cocoa Beach, Brevard  County         Walking               Cody High    M
# 3               Cairns Aquarium  Feeding sharks                    male    M
# 4                Off Land's End         Fishing            Max Berryman    M
#
#   age            time          species_  \
# 0  57           18h00       White shark
# 1  18  Late afternoon       Tiger shark
# 2  15           17h00    Bull shark, 6'
# 3  32         Morning   Grey reef shark
# 4  21           08h15  Invalid incident
#
#                                                 href      siglo fatal_(y/n)  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           Y
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
#
#                                               injury         date
# 0  No injury to occupant, outrigger canoe and pad...  25-Jun-2018
# 1                                              FATAL  03-Jun-2018
# 2                              Lower left leg bitten  26-May-2018
# 3  Minor bite to hand by captive shark. PROVOKED ...  24-May-2018
# 4  Injured by teeth of a dead porbeagle shark he ...  13-May-2018

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1672 entries, 0 to 1671
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   case_number   1672 non-null   object
#  1   unnamed:_0_x  1672 non-null   int64
#  2   year          1672 non-null   float64
#  3   type          1672 non-null   object
#  4   country       1662 non-null   object
#  5   area          1626 non-null   object
#  6   location      1621 non-null   object
#  7   activity      1641 non-null   object
#  8   name          1663 non-null   object
#  9   sex_          1658 non-null   object
#  10  age           1518 non-null   object
#  11  time          1512 non-null   object
#  12  species_      1546 non-null   object
#  13  href          1672 non-null   object
#  14  siglo         1672 non-null   object
#  15  fatal_(y/n)   1585 non-null   object
#  16  injury        1664 non-null   object
#  17  date          1672 non-null   object
# dtypes: float64(1), int64(1), object(16)
# memory usage: 235.2+ KB

# %% [markdown]
# ### 1. Cread una columna nueva y una función que nos de el mes en el que ocurrió el ataque.
#
# Tened en cuenta que no todas las filas tienen la misma estructura y que puede que no haya la información de mes.
# En ese caso devolved un nulo (NaN).
#
# 💡 Pista 💡Podéis usar regex.

# %%
# date es object

df["date"].unique()
# Out:
# array(['25-Jun-2018', '03-Jun-2018', '26-May-2018', ..., '1900-1905',
#        '1883-1889', '1845-1853'], dtype=object)

# %%
# Creamos una función que gracias a nuestro patrón, nos devuelva solo el mes en que se produjo el ataque:

def devolver_mes(fecha):
    # Definimos el patrón con regex:
    patron = "\-(Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)\-"
    
    try:
        return re.findall(patron, fecha)[0].replace("-", " ")
    except:
        return np.nan

# %%
df["month"] = df["date"].apply(devolver_mes)

# %%
# Comprobamos que los meses se ven correctamente:

df.head()
# Out:
#     case_number  unnamed:_0_x    year        type    country        area  \
# 0    2018.06.25             0  2018.0     Boating        USA  California
# 1  2018.06.03.a             6  2018.0  Unprovoked     BRAZIL  Pernambuco
# 2  2018.05.26.b             8  2018.0  Unprovoked        USA     Florida
# 3    2018.05.24            10  2018.0    Provoked  AUSTRALIA  Queensland
# 4  2018.05.13.a            13  2018.0     Invalid    ENGLAND    Cornwall
#
#                        location        activity                    name sex_  \
# 0   Oceanside, San Diego County        Paddling             Julie Wolfe    F
# 1         Piedade Beach, Recife        Swimming  Jose Ernesto da Silva     M
# 2  Cocoa Beach, Brevard  County         Walking               Cody High    M
# 3               Cairns Aquarium  Feeding sharks                    male    M
# 4                Off Land's End         Fishing            Max Berryman    M
#
#   age            time          species_  \
# 0  57           18h00       White shark
# 1  18  Late afternoon       Tiger shark
# 2  15           17h00    Bull shark, 6'
# 3  32         Morning   Grey reef shark
# 4  21           08h15  Invalid incident
#
#                                                 href      siglo fatal_(y/n)  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           Y
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
#
#                                               injury         date month
# 0  No injury to occupant, outrigger canoe and pad...  25-Jun-2018   Jun
# 1                                              FATAL  03-Jun-2018   Jun
# 2                              Lower left leg bitten  26-May-2018   May
# 3  Minor bite to hand by captive shark. PROVOKED ...  24-May-2018   May
# 4  Injured by teeth of a dead porbeagle shark he ...  13-May-2018   May

# %%
# Y qué los que no tenían mes, se han quedado como nulos:

df.tail()
# Out:
#      case_number  unnamed:_0_x  year        type             country  \
# 1667     ND.0005          6297   0.0  Unprovoked           AUSTRALIA
# 1668     ND.0004          6298   0.0  Unprovoked           AUSTRALIA
# 1669     ND.0003          6299   0.0  Unprovoked                 USA
# 1670     ND.0002          6300   0.0  Unprovoked              PANAMA
# 1671     ND.0001          6301   0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    area                             location      activity  \
# 1667  Western Australia                          Roebuck Bay        Diving
# 1668  Western Australia                                  NaN  Pearl diving
# 1669     North Carolina                       Ocracoke Inlet      Swimming
# 1670                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 1671   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        name sex_  age time species_  \
# 1667                   male    M  NaN  NaN      NaN
# 1668                  Ahmun    M  NaN  NaN      NaN
# 1669  Coast Guard personnel    M  NaN  NaN      NaN
# 1670        Jules Patterson    M  NaN  NaN      NaN
# 1671                   male    M   15  NaN      NaN
#
#                                                    href     siglo fatal_(y/n)  \
# 1667  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX           Y
# 1668  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX           Y
# 1669  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX           Y
# 1670  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX           Y
# 1671  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XX           Y
#
#                                                  injury         date month
# 1667                                              FATAL  Before 1903   NaN
# 1668                                              FATAL  Before 1903   NaN
# 1669                                              FATAL    1900-1905   NaN
# 1670                                              FATAL    1883-1889   NaN
# 1671  FATAL. "Shark bit him in half, carrying away t...    1845-1853   NaN

# %%
df["month"].value_counts()
# Out:
# Aug    156
# Sep    153
# Oct    146
# Jul    143
# Jun    136
# Jan    127
# Apr    124
# May    105
# Dec    104
# Mar    102
# Nov     99
# Feb     96
# Name: month, dtype: int64

# %%
df["month"].isnull().sum()
# Out:
# 181

# %% [markdown]
# ### 2. Vamos con la columna fatal_(y/n). Lo primero que tenéis que hacer es evaluar los valores únicos que hay.
#
# Esperaríamos tener solo dos valores: y y n, pero tristemente no será así 😭.
# Cread una columna nueva y una función que devuelva únicamente y o n y que devuelva un nulo (NaN) si no se encuentra el valor.

# %%
df["fatal_(y/n)"].value_counts()
# Out:
# N          1256
# Y           317
# UNKNOWN       8
#  N            2
# M             1
# 2017          1
# Name: fatal_(y/n), dtype: int64

# %%
def cambiar_fatal(fatal):
    if fatal == 'N' or fatal == 'Y':
        return fatal
    else:
        return np.nan

# %%
df["fatal"] = df["fatal_(y/n)"].apply(cambiar_fatal)
df.head(10)
# Out:
#     case_number  unnamed:_0_x    year        type       country  \
# 0    2018.06.25             0  2018.0     Boating           USA
# 1  2018.06.03.a             6  2018.0  Unprovoked        BRAZIL
# 2  2018.05.26.b             8  2018.0  Unprovoked           USA
# 3    2018.05.24            10  2018.0    Provoked     AUSTRALIA
# 4  2018.05.13.a            13  2018.0     Invalid       ENGLAND
# 5  2018.04.28.b            18  2018.0  Unprovoked    COSTA RICA
# 6  2018.04.25.a            21  2018.0  Unprovoked     AUSTRALIA
# 7    2018.04.23            23  2018.0  Unprovoked      MALDIVES
# 8    2018.04.22            24  2018.0  Unprovoked  SOUTH AFRICA
# 9    2018.04.03            34  2018.0  Unprovoked  SOUTH AFRICA
#
#                     area                        location        activity  \
# 0             California     Oceanside, San Diego County        Paddling
# 1             Pernambuco           Piedade Beach, Recife        Swimming
# 2                Florida    Cocoa Beach, Brevard  County         Walking
# 3             Queensland                 Cairns Aquarium  Feeding sharks
# 4               Cornwall                  Off Land's End         Fishing
# 5           Cocos Island                       Manuelita    Scuba diving
# 6      Western Australia         Surfers Point, Prevelly         Surfing
# 7      Alifu Alifu Atoll                       Madoogali         Fishing
# 8  Western Cape Province  Robberg Beach, Plettenberg Bay   Paddle-skiing
# 9  Eastern Cape Province                 St. Francis Bay         Surfing
#
#                      name sex_ age            time            species_  \
# 0             Julie Wolfe    F  57           18h00         White shark
# 1  Jose Ernesto da Silva     M  18  Late afternoon         Tiger shark
# 2               Cody High    M  15           17h00      Bull shark, 6'
# 3                    male    M  32         Morning     Grey reef shark
# 4            Max Berryman    M  21           08h15    Invalid incident
# 5                    male    M  30           10h40         Tiger shark
# 6               Rob Bruce    M  60           09h30           3 m shark
# 7           Ahmed Rasheed    M  32           21h50         Tiger shark
# 8                    male    M  33           09h40  White shark, 2.5 m
# 9            Ross Spowart    M  19           15h00         White shark
#
#                                                 href      siglo fatal_(y/n)  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           Y
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
# 5  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
# 6  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
#
#                                               injury         date month fatal
# 0  No injury to occupant, outrigger canoe and pad...  25-Jun-2018   Jun     N
# 1                                              FATAL  03-Jun-2018   Jun     Y
# 2                              Lower left leg bitten  26-May-2018   May     N
# 3  Minor bite to hand by captive shark. PROVOKED ...  24-May-2018   May     N
# 4  Injured by teeth of a dead porbeagle shark he ...  13-May-2018   May     N
# 5                    No injury, shark bit scuba gear  28-Apr-2018   Apr     N
# 6              No injury, knocked off board by shark  25-Apr-2018   Apr     N
# 7                                 5-inch cut to hand  23-Apr-2018   Apr     N
# 8                   No injury, shark bit hole in ski  22-Apr-2018   Apr     N
# 9               Lacerations to left knee & lower leg  03-Apr-2018   Apr     N

# %%
df["fatal"].unique()
# Out:
# array(['N', 'Y', nan], dtype=object)

# %%
df["fatal"].value_counts()
# Out:
# N    1256
# Y     317
# Name: fatal, dtype: int64

# %%
df["fatal"].isnull().sum()
# Out:
# 99

# %% [markdown]
# ### 3. Seguid la misma lógica que en el ejercicio anterior pero con la columna sex.
#
# Pero en este caso vamos a incluir un retito más: En este caso querremos tener dos valores únicos F y M. De nuevo en la columna hay otros carácteres raros como 'M ', 'lli', 'N', '.'. En esos casos, queremos que se reemplacen por M o F de forma aleatoria (tendréis que usar la librería random). En caso de que sea nulo, que la función devuelva nulo (np.nan).

# %%
df["sex_"].value_counts()
# Out:
# M      1435
# F       222
# lli       1
# Name: sex_, dtype: int64

# %%
df["sex_"].isnull().sum()

# %%
def cambiar_sex(sex):
    if sex == 'M' or sex == 'F':
        return sex
    elif str(sex).lower() == "nan":
        return np.nan
    else:
        if np.random.randint(0,2) == 0:
            return 'F'
        else:
            return 'M'

# %%
df["sex"] = df["sex_"].apply(cambiar_sex)
df.head()
# Out:
#     case_number  unnamed:_0_x    year        type       country  \
# 0    2018.06.25             0  2018.0     Boating           USA
# 1  2018.06.03.a             6  2018.0  Unprovoked        BRAZIL
# 2  2018.05.26.b             8  2018.0  Unprovoked           USA
# 3    2018.05.24            10  2018.0    Provoked     AUSTRALIA
# 4  2018.05.13.a            13  2018.0     Invalid       ENGLAND
# 5  2018.04.28.b            18  2018.0  Unprovoked    COSTA RICA
# 6  2018.04.25.a            21  2018.0  Unprovoked     AUSTRALIA
# 7    2018.04.23            23  2018.0  Unprovoked      MALDIVES
# 8    2018.04.22            24  2018.0  Unprovoked  SOUTH AFRICA
# 9    2018.04.03            34  2018.0  Unprovoked  SOUTH AFRICA
#
#                     area                        location        activity  \
# 0             California     Oceanside, San Diego County        Paddling
# 1             Pernambuco           Piedade Beach, Recife        Swimming
# 2                Florida    Cocoa Beach, Brevard  County         Walking
# 3             Queensland                 Cairns Aquarium  Feeding sharks
# 4               Cornwall                  Off Land's End         Fishing
# 5           Cocos Island                       Manuelita    Scuba diving
# 6      Western Australia         Surfers Point, Prevelly         Surfing
# 7      Alifu Alifu Atoll                       Madoogali         Fishing
# 8  Western Cape Province  Robberg Beach, Plettenberg Bay   Paddle-skiing
# 9  Eastern Cape Province                 St. Francis Bay         Surfing
#
#                      name sex_  ...            time            species_  \
# 0             Julie Wolfe    F  ...           18h00         White shark
# 1  Jose Ernesto da Silva     M  ...  Late afternoon         Tiger shark
# 2               Cody High    M  ...           17h00      Bull shark, 6'
# 3                    male    M  ...         Morning     Grey reef shark
# 4            Max Berryman    M  ...           08h15    Invalid incident
# 5                    male    M  ...           10h40         Tiger shark
# 6               Rob Bruce    M  ...           09h30           3 m shark
# 7           Ahmed Rasheed    M  ...           21h50         Tiger shark
# 8                    male    M  ...           09h40  White shark, 2.5 m
# 9            Ross Spowart    M  ...           15h00         White shark
#
#                                                 href      siglo fatal_(y/n)  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           Y
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
# 5  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
# 6  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
# 7  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
# 8  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
# 9  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI           N
#
#                                               injury         date month fatal  \
# 0  No injury to occupant, outrigger canoe and pad...  25-Jun-2018   Jun     N
# 1                                              FATAL  03-Jun-2018   Jun     Y
# 2                              Lower left leg bitten  26-May-2018   May     N
# 3  Minor bite to hand by captive shark. PROVOKED ...  24-May-2018   May     N
# 4  Injured by teeth of a dead porbeagle shark he ...  13-May-2018   May     N
# 5                    No injury, shark bit scuba gear  28-Apr-2018   Apr     N
# 6              No injury, knocked off board by shark  25-Apr-2018   Apr     N
# 7                                 5-inch cut to hand  23-Apr-2018   Apr     N
# 8                   No injury, shark bit hole in ski  22-Apr-2018   Apr     N
# 9               Lacerations to left knee & lower leg  03-Apr-2018   Apr     N
#
#   sex
# 0   F
# 1   M
# 2   M
# 3   M
# 4   M
# 5   M
# 6   M
# 7   M
# 8   M
# 9   M
#
# [10 rows x 21 columns]

# %%
df["sex_"].value_counts()
# Out:
# array(['F', 'M', None], dtype=object)

# %%
df["sex_"].isnull().sum()

# %% [markdown]
# ### 4. Una vez que hayáis terminado eliminad las columnas originales conservando las nuevas.

# %%
df.drop(["date", "fatal_(y/n)", "sex_"], axis = 1, inplace = True)

# %%
df.head(1)
# Out:
#   case_number  unnamed:_0_x    year     type country        area  \
# 0  2018.06.25             0  2018.0  Boating     USA  California
#
#                       location  activity         name age   time     species_  \
# 0  Oceanside, San Diego County  Paddling  Julie Wolfe  57  18h00  White shark
#
#                                                 href      siglo  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...  siglo-XXI
#
#                                               injury month fatal sex
# 0  No injury to occupant, outrigger canoe and pad...   Jun     N   F

# %% [markdown]
# ### 5. Guardad el dataframe en un csv que usaremos más adelante.

# %%
df.to_csv("datos/attacks_pandas7.csv")
